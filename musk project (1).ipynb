# %%
import pandas as pd

# %%
data = pd.read_csv("musk_csv.csv")

# %%
data.head(5)
# Out:
#    ID molecule_name conformation_name  f1   f2   f3  f4   f5  f6  f7  ...  \
# 0   1      MUSK-211           211_1+1  46 -108  -60 -69 -117  49  38  ...
# 1   2      MUSK-211          211_1+10  41 -188 -145  22 -117  -6  57  ...
# 2   3      MUSK-211          211_1+11  46 -194 -145  28 -117  73  57  ...
# 3   4      MUSK-211          211_1+12  41 -188 -145  22 -117  -7  57  ...
# 4   5      MUSK-211          211_1+13  41 -188 -145  22 -117  -7  57  ...
#
#    f158  f159  f160  f161  f162  f163  f164  f165  f166  class
# 0  -308    52    -7    39   126   156   -50  -112    96      1
# 1   -59    -2    52   103   136   169   -61  -136    79      1
# 2  -134  -154    57   143   142   165   -67  -145    39      1
# 3   -60    -4    52   104   136   168   -60  -135    80      1
# 4   -60    -4    52   104   137   168   -60  -135    80      1
#
# [5 rows x 170 columns]

# %%
data.tail(5)
# Out:
#         ID  molecule_name conformation_name  f1   f2  f3   f4   f5   f6   f7  \
# 6593  6594  NON-MUSK-jp13          jp13_2+5  51 -123 -23 -108 -117  134 -160
# 6594  6595  NON-MUSK-jp13          jp13_2+6  44 -104 -19 -105 -117  142 -165
# 6595  6596  NON-MUSK-jp13          jp13_2+7  44 -102 -19 -104 -117   72 -165
# 6596  6597  NON-MUSK-jp13          jp13_2+8  51 -121 -23 -106 -117   63 -161
# 6597  6598  NON-MUSK-jp13          jp13_2+9  51 -122 -23 -106 -117  190 -161
#
#       ...  f158  f159  f160  f161  f162  f163  f164  f165  f166  class
# 6593  ...   -66   164   -14   -29   107   171   -44  -115   118      0
# 6594  ...   -51   166    -9   150   129   158   -66  -144    -5      0
# 6595  ...    90   117    -8   150   130   159   -66  -144    -6      0
# 6596  ...    86    99   -14   -31   106   171   -44  -116   117      0
# 6597  ...    40   124   -14   -30   107   171   -44  -115   118      0
#
# [5 rows x 170 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6598 entries, 0 to 6597
# Columns: 170 entries, ID to class
# dtypes: int64(168), object(2)
# memory usage: 8.6+ MB

# %%
data.describe()
# Out:
#                ID           f1           f2           f3           f4  \
# count  6598.00000  6598.000000  6598.000000  6598.000000  6598.000000
# mean   3299.50000    58.945135  -119.128524   -73.146560    -0.628372
# std    1904.82287    53.249007    90.813375    67.956235    80.444617
# min       1.00000   -31.000000  -199.000000  -167.000000  -114.000000
# 25%    1650.25000    37.000000  -193.000000  -137.000000   -70.000000
# 50%    3299.50000    44.000000  -149.000000   -99.000000   -25.000000
# 75%    4948.75000    53.000000   -95.000000   -19.000000    42.000000
# max    6598.00000   292.000000    95.000000    81.000000   161.000000
#
#                 f5           f6           f7           f8           f9  ...  \
# count  6598.000000  6598.000000  6598.000000  6598.000000  6598.000000  ...
# mean   -103.533495    18.359806   -14.108821    -1.858290   -86.003031  ...
# std      64.387559    80.593655   115.315673    90.372537   108.326676  ...
# ...

# %%
data.isnull().sum()
# Out:
# ID                   0
# molecule_name        0
# conformation_name    0
# f1                   0
# f2                   0
#                     ..
# f163                 0
# f164                 0
# f165                 0
# f166                 0
# class                0
# Length: 170, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
molecule=LabelEncoder()

# %%
data["molecule_name"]=molecule.fit_transform(data["molecule_name"])

# %%
data.head(5)
# Out:
#    ID  molecule_name conformation_name  f1   f2   f3  f4   f5  f6  f7  ...  \
# 0   1              0           211_1+1  46 -108  -60 -69 -117  49  38  ...
# 1   2              0          211_1+10  41 -188 -145  22 -117  -6  57  ...
# 2   3              0          211_1+11  46 -194 -145  28 -117  73  57  ...
# 3   4              0          211_1+12  41 -188 -145  22 -117  -7  57  ...
# 4   5              0          211_1+13  41 -188 -145  22 -117  -7  57  ...
#
#    f158  f159  f160  f161  f162  f163  f164  f165  f166  class
# 0  -308    52    -7    39   126   156   -50  -112    96      1
# 1   -59    -2    52   103   136   169   -61  -136    79      1
# 2  -134  -154    57   143   142   165   -67  -145    39      1
# 3   -60    -4    52   104   136   168   -60  -135    80      1
# 4   -60    -4    52   104   137   168   -60  -135    80      1
#
# [5 rows x 170 columns]

# %%
data.drop(["conformation_name"],axis=1,inplace=True)

# %%
data.head()
# Out:
#    ID  molecule_name  f1   f2   f3  f4   f5  f6  f7   f8  ...  f158  f159  \
# 0   1              0  46 -108  -60 -69 -117  49  38 -161  ...  -308    52
# 1   2              0  41 -188 -145  22 -117  -6  57 -171  ...   -59    -2
# 2   3              0  46 -194 -145  28 -117  73  57 -168  ...  -134  -154
# 3   4              0  41 -188 -145  22 -117  -7  57 -170  ...   -60    -4
# 4   5              0  41 -188 -145  22 -117  -7  57 -170  ...   -60    -4
#
#    f160  f161  f162  f163  f164  f165  f166  class
# 0    -7    39   126   156   -50  -112    96      1
# 1    52   103   136   169   -61  -136    79      1
# 2    57   143   142   165   -67  -145    39      1
# 3    52   104   136   168   -60  -135    80      1
# 4    52   104   137   168   -60  -135    80      1
#
# [5 rows x 169 columns]

# %%
data.shape
# Out:
# (6598, 169)

# %%
data
# Out:
#         ID  molecule_name  f1   f2   f3   f4   f5   f6   f7   f8  ...  f158  \
# 0        1              0  46 -108  -60  -69 -117   49   38 -161  ...  -308
# 1        2              0  41 -188 -145   22 -117   -6   57 -171  ...   -59
# 2        3              0  46 -194 -145   28 -117   73   57 -168  ...  -134
# 3        4              0  41 -188 -145   22 -117   -7   57 -170  ...   -60
# 4        5              0  41 -188 -145   22 -117   -7   57 -170  ...   -60
# ...    ...            ...  ..  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 6593  6594            101  51 -123  -23 -108 -117  134 -160   82  ...   -66
# 6594  6595            101  44 -104  -19 -105 -117  142 -165   68  ...   -51
# 6595  6596            101  44 -102  -19 -104 -117   72 -165   65  ...    90
# 6596  6597            101  51 -121  -23 -106 -117   63 -161   79  ...    86
# 6597  6598            101  51 -122  -23 -106 -117  190 -161   80  ...    40
#
# ...

# %%
data.columns.unique()
# Out:
# Index(['ID', 'molecule_name', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8',
#        ...
#        'f158', 'f159', 'f160', 'f161', 'f162', 'f163', 'f164', 'f165', 'f166',
#        'class'],
#       dtype='object', length=169)

# %%
data.dtypes
# Out:
# ID               int64
# molecule_name    int32
# f1               int64
# f2               int64
# f3               int64
#                  ...
# f163             int64
# f164             int64
# f165             int64
# f166             int64
# class            int64
# Length: 169, dtype: object

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
training_data=data.copy()

# %%
training_data
# Out:
#         ID  molecule_name  f1   f2   f3   f4   f5   f6   f7   f8  ...  f158  \
# 0        1              0  46 -108  -60  -69 -117   49   38 -161  ...  -308
# 1        2              0  41 -188 -145   22 -117   -6   57 -171  ...   -59
# 2        3              0  46 -194 -145   28 -117   73   57 -168  ...  -134
# 3        4              0  41 -188 -145   22 -117   -7   57 -170  ...   -60
# 4        5              0  41 -188 -145   22 -117   -7   57 -170  ...   -60
# ...    ...            ...  ..  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 6593  6594            101  51 -123  -23 -108 -117  134 -160   82  ...   -66
# 6594  6595            101  44 -104  -19 -105 -117  142 -165   68  ...   -51
# 6595  6596            101  44 -102  -19 -104 -117   72 -165   65  ...    90
# 6596  6597            101  51 -121  -23 -106 -117   63 -161   79  ...    86
# 6597  6598            101  51 -122  -23 -106 -117  190 -161   80  ...    40
#
# ...

# %%
training_data.drop(["molecule_name"],axis=1,inplace=True)

# %%
training_data
# Out:
#         ID  f1   f2   f3   f4   f5   f6   f7   f8   f9  ...  f158  f159  f160  \
# 0        1  46 -108  -60  -69 -117   49   38 -161   -8  ...  -308    52    -7
# 1        2  41 -188 -145   22 -117   -6   57 -171  -39  ...   -59    -2    52
# 2        3  46 -194 -145   28 -117   73   57 -168  -39  ...  -134  -154    57
# 3        4  41 -188 -145   22 -117   -7   57 -170  -39  ...   -60    -4    52
# 4        5  41 -188 -145   22 -117   -7   57 -170  -39  ...   -60    -4    52
# ...    ...  ..  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 6593  6594  51 -123  -23 -108 -117  134 -160   82 -230  ...   -66   164   -14
# 6594  6595  44 -104  -19 -105 -117  142 -165   68 -225  ...   -51   166    -9
# 6595  6596  44 -102  -19 -104 -117   72 -165   65 -219  ...    90   117    -8
# 6596  6597  51 -121  -23 -106 -117   63 -161   79 -224  ...    86    99   -14
# 6597  6598  51 -122  -23 -106 -117  190 -161   80 -227  ...    40   124   -14
#
# ...

# %%
data
# Out:
#         ID  molecule_name  f1   f2   f3   f4   f5   f6   f7   f8  ...  f158  \
# 0        1              0  46 -108  -60  -69 -117   49   38 -161  ...  -308
# 1        2              0  41 -188 -145   22 -117   -6   57 -171  ...   -59
# 2        3              0  46 -194 -145   28 -117   73   57 -168  ...  -134
# 3        4              0  41 -188 -145   22 -117   -7   57 -170  ...   -60
# 4        5              0  41 -188 -145   22 -117   -7   57 -170  ...   -60
# ...    ...            ...  ..  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 6593  6594            101  51 -123  -23 -108 -117  134 -160   82  ...   -66
# 6594  6595            101  44 -104  -19 -105 -117  142 -165   68  ...   -51
# 6595  6596            101  44 -102  -19 -104 -117   72 -165   65  ...    90
# 6596  6597            101  51 -121  -23 -106 -117   63 -161   79  ...    86
# 6597  6598            101  51 -122  -23 -106 -117  190 -161   80  ...    40
#
# ...

# %%
output_data=data["molecule_name"]

# %%
from sklearn.model_selection import train_test_split

# %%
X,x_test,Y,y_test=train_test_split(training_data,
                                  output_data,
                                  test_size=0.2,
                                  random_state=23)

# %%
model = KNeighborsClassifier(n_neighbors=12)

# %%
model.fit(X, Y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=12, p=2,
#                      weights='uniform')

# %%
prediction = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
accuracy_score(y_test, prediction)
# Out:
# 0.931060606060606
